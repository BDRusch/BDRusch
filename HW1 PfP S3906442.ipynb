# %%
#Homework 1 
# Byron Rusch 
#S3906442

#1 Write a program that gives the roots of the quadratic equation
# y= ax^2 + bx + c

#inputs
a = input("input a")
b = input("input b")
c = input("input c")

print(a)
print(b)
print(c)

D = (eval(b))**2 - 4*eval(a)*eval(c) #discriminant

if D < 0:
  print("There are no solutions")

elif D > 0:
  rootD = (D)**(1/2)
  print("There are two solutions")
  x1 = ((-1*eval(b)) + (rootD))/(2*(eval(a)))
  x2 = ((-1*eval(b)) - (rootD))/(2*(eval(a)))
  print(f"x1 = {x1} and x2 = {x2}")

elif D == 0:
  print("There is one solutions")
  x = (-1*eval(b))/(2*(eval(a)))
  print(x)
# Out:
# input a5
# input b3
# input c2
# 5
# 3
# 2
# There are no solutions

# %%
#2 Write a program that generates the Fibonacci series in a list, up to and including the nth term, that was given as a user input
Fibonacci = [0,1]
userin = input("How many terms?")
n = eval(userin)
n1 = 0
n2 = 1

for x in range(2,n):
  n = n1 + n2
  n1 = n2
  n2 = n
  Fibonacci.append(n)
  a = (Fibonacci[x]) -(Fibonacci[x - 1])
  if a > 50:
    print("the difference between two consecutive numbers in sequence is greater than 50 at x=", x)
  if int(Fibonacci[x]) % 3 == 0 :
    print(int(Fibonacci[x]),"the term is divisable by 3 at x=", x)

print(Fibonacci)
# Out:
# How many terms?1
# [0, 1]

# %%
#3 Use a while loop to approximate the the infinite sum
x = 0 
total = 0
while True :
  total += (1/((4*(x)**2) - 1))
  x += 1
  if total > -0.5001:
    break
print(f'at {int(x-1)} iterations the result is {total - (1/((4*(x)**2) - 1))} and at {int(x)} iterations the result is {total}')
# Out:
# at 2500 iterations the result is -0.5001000199720195 and at 2501 iterations the result is -0.5000999800039987
