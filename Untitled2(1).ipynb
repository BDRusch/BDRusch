# %%
pip install pykrakenapi
ticker = k.get_ticker_information('BTCUSD')
ticker.T
# Out:
#   File "<ipython-input-2-12ae65fe96cc>", line 1
#     pip install pykrakenapi
#               ^
# SyntaxError: invalid syntax
