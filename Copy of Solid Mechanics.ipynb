# %%
#Mesh Size vs Average Stress in x direction
import numpy as np
import matplotlib.pyplot as plt

#Max Mesh Sizes
Max_Mesh_size = np.array([0.01, 0.02, 0.037, 0.053, 0.067, 0.1, 0.13, 0.2, 0.33])
Min_Mesh_Size = np.array([0.00005, 0.000075, 0.000125, 0.0003, 0.0003, 0.002, 0.006, 0.016, 0.05])
#Average Axial Stress Sig_xx acteing on Overhang x10^8 N/m^2
Closed_Ave_Metal_Lead_Sig_xx = np.array([2.2828, 2.28296, 2.28316, 2.8348, 2.8384, 2.842, 2.844, 2.8526, 2.8496])

#CLOSED MODEL
#Comaprison of Maximums from Gaph Compared to Max Method of Sig_xx at Metal-Polyimide Interface x10^8 N/m^2
Closed_Metal_Interface_Max_Sig_xx = np.array([1.6478, 1.514, 1.4368, 1.3606, 1.3277, 1.3513, 1.3456, 1.3749, 1.2812])
Closed_Metal_Interface_Max_Graph_Sig_xx = np.array([1.6478, 1.514, 1.43681, 1.36057, 1.32772, 1.3513, 1.3456, 1.37491, 1.2812])

#Comaprison of Maximums from Gaph Compared to Max Method of Sig_yy at Metal-Polyimide Interface x10^8 N/m^2
Closed_Metal_Interface_Max_Sig_yy = np.array([0.10348, 0.10622, 0.10662, 0.10924, 0.08622, 0.16618, 0.13199, 0.271315, 0.0812])
Closed_Metal_Interface_Max_Graph_Sig_yy = np.array([-0.34665, -0.28255, -0.216274, -0.165763, -0.15097, -0.184205, -0.158164, -0.3634, -0.105245])

#Comaprison of Maximums from Gaph Compared to Max Method of Sig_xy at Metal-Polyimide Interface  x10^8 N/m^2
Closed_Metal_Interface_Max_Sig_xy = np.array([-0.043884, -0.045621, -0.037386, -0.030203, -0.010208, -0.024335, -0.014856, 0.0028795, -0.011638])
# x10^8 N/m^2
Closed_Metal_Interface_Max_Graph_Sig_xy = np.array([-0.2094315, -0.296754, -0.299894, -0.301426, -0.320844, -0.3187, -0.318875, -0.31796, -0.31538])
#irregular at position nead the junction of the interface and the overhang plot point of Sig_xy x10^8 N/m^2 graph max at Mesh = 0,01m 
Irregular_Closed_Metal_Interface_Max_Graph_Sig_xy = np.array([-0.3141667])


#Comaprison of Maximums from Gaph Compared to Max Method of Sig_xx at Polyimide-Substrate Interface x10^8 N/m^2
Closed_Substrate_Interface_Max_Sig_xx = np.array([2.1892, 1.7172, 1.4097, 1.2285, 1.1174, 0.93833, 0.93583, 0.83712, 0.70522])
Closed_Substrate_Interface_Max_Graph_Sig_xx = np.array([2.1892, 1.717205, 1.40969, 1.22852, 1.11736, 0.93833, 0.935829, 0.83712, 0.70522])

#Comaprison of Maximums from Gaph Compared to Max Method of Sig_yy at Polyimide-Substrate Interface x10^8 N/m^2
Closed_Substrate_Interface_Max_Sig_yy = np.array([2.7302, 2.0222, 1.5610, 1.2892, 1.1225, 0.85392, 0.85017, 0.70211, 0.50426])
Closed_Substrate_Interface_Max_Graph_Sig_yy = np.array([2.7302, 2.02224, 1.56096, 1.28921, 1.12245, 0.853923, 0.85017, 0.70211, 0.504258])

#Comaprison of Maximums from Gaph Compared to Max Method of Sig_yy at Polyimide-Substrate Interface N/m^2
Closed_Substrate_Interface_Max_Sig_xy = np.array([-0.0000057259, -0.000025235, -0.000084568, -0.00020429, -0.00040484, -0.00084012, 0.000, -0.00151870, -0.00320860])
#Graphical values of order x10^8 N/m^2
Closed_Substrate_Interface_Max_Graph_Sig_xy = np.array([-1.1345, -0.888838, -0.75077, -0.641008, -0.58672, -0.538955, -0.54029, -0.57288, -0.44444])


#OPEN MODEL
#Comaprison of Maximums from Gaph of Sig_xx at Metal-Polyimide Interface x10^7 N/m^2
Open_Metal_Interface_Max_Graph_Sig_xx = np.array([3.617, 3.6347, 3.6656, 3.7203, 3.7375, 3.7237, 3.7447, 3.7096, 3.7485])

#Comaprison of Maximums from Gaph of Sig_yy at Metal-Polyimide Interface x10^7 N/m^2
Open_Metal_Interface_Max_Graph_Sig_yy = np.array([-1.2405, -1.0567, -0.8695, -0.76646, -0.67363, -0.7132, -0.69144, -0.693925, -0.506345])

#Comaprison of Maximums from Gaph of Sig_xy at Metal-Polyimide Interface x10^7 N/m^2
Open_Metal_Interface_Max_Graph_Sig_xy = np.array([1.387, 1.258, 1.1702, 1.1109, 0.98256, 0.9895, 0.9402, 1.0055, 0.98783])

#Comaprison of Maximums from Gaph of Sig_xx at Polyimide-Substrate Interface x10^7 N/m^2
Open_Substrate_Interface_Max_Graph_Sig_xx = np.array([13.567, 10.603, 8.7026, 7.6131, 6.9702, 6.0149, 5.968, 5.6285, 4.854])

#Comaprison of Maximums from Gaph of Sig_xx at Polyimide-Substrate Interface x10^7 N/m^2
Open_Substrate_Interface_Max_Graph_Sig_yy = np.array([14.815, 10.369, 7.5182, 5.884, 4.9195, 3.4867, 3.4163, 2.907, 1.746])

#Comaprison of Maximums from Gaph of Sig_xx at Polyimide-Substrate Interface x10^7 N/m^2
Open_Substrate_Interface_Max_Graph_Sig_xy = np.array([-7.12576, -5.61943, -4.76563, -4.0792, -3.7184, -3.36939, -3.3566, -3.15619, -2.683])


#Graph Mesh Size vs Average Stress in the Overhang
plt.figure(figsize = (10,10))
plt.scatter( Max_Mesh_size, Closed_Ave_Metal_Lead_Sig_xx, label = r'Average $\sigma_{xx}$ ')
plt.title(r'Average Stress of Metal Lead Overhang vs Mesh Size')
plt.xlabel(r'Mesh Size [m]')
plt.ylabel(r'$\sigma_{xx}$ $[N/m^{2}]$')
plt.xscale('log')
plt.legend()
plt.show()

#Graph Closed Model Metal-Polyimide Interface Mesh Size vs Sig_xx comparing Max vs Max_Graph
plt.figure(figsize = (10,10))
plt.scatter(Max_Mesh_size, Closed_Metal_Interface_Max_Sig_xx, label = r'Max $\sigma_{xx}$')
plt.scatter(Max_Mesh_size, Closed_Metal_Interface_Max_Graph_Sig_xx, label = r'Max Graphical $\sigma_{xx}$')
plt.title(r'Maximum $Stress_{xx}$ along Metal Lead-Polyimide Interface vs Mesh Size for Closed Model')
plt.xlabel(r'Mesh Size [m]')
plt.ylabel(r'$\sigma_{xx}$ $ x 10^{8}$ $[N/m^{2}]$')
plt.xscale('log')
plt.legend()
plt.show()

#Graph Closed Model Metal-Polyimide Interface Mesh Size vs  Sig_yy  comparing Max vs Max_Graph
plt.figure(figsize = (10,10))
plt.scatter(Max_Mesh_size, Closed_Metal_Interface_Max_Sig_yy,  label = r'Max $\sigma_{yy}$')
plt.scatter(Max_Mesh_size, Closed_Metal_Interface_Max_Graph_Sig_yy, label = r'Max Graphical $\sigma_{yy}$')
plt.title(r'Maximum $Stress_{yy}$ along Metal Lead-Polyimide Interface vs Mesh Size for Closed Model')
plt.xlabel(r'Mesh Size [m]')
plt.ylabel(r'$\sigma_{yy}$ $ x 10^{8}$ $[N/m^{2}]$')
plt.xscale('log')
plt.legend()
plt.show()

#Graph Closed Model Metal-Polyimide Interface Mesh Size vs Sig_xy comparing Max vs Max_Graph
plt.figure(figsize = (10,10))
plt.scatter(Max_Mesh_size, Closed_Metal_Interface_Max_Sig_xy,  label = r'Max $\sigma_{xy}$')
plt.scatter(Max_Mesh_size, Closed_Metal_Interface_Max_Graph_Sig_xy, label = r'Max Graphical $\sigma_{xy}$')
plt.title(r'Maximum $Stress_{xy}$ along Metal Lead-Polyimide Interface vs Mesh Size for Closed Model')
plt.xlabel(r'Mesh Size [m]')
plt.ylabel(r'$\sigma_{xy}$ $ x 10^{8}$ $[N/m^{2}]$')
plt.xscale('log')
plt.legend()
plt.show()

#Graph of Irregularity Closed Sig_xy Max_Graph
plt.figure(figsize = (10,10))
plt.scatter(Max_Mesh_size, Closed_Metal_Interface_Max_Graph_Sig_xy, label = r'Max Graphical $\sigma_{xy}$')
plt.scatter(Max_Mesh_size[0], Irregular_Closed_Metal_Interface_Max_Graph_Sig_xy, label = 'Irregularity')
plt.title(r'Maximum Shear Stress along Polyimide-Substrate Interface vs Mesh Size for Closed Model')
plt.xlabel(r'Mesh Size [m]')
plt.ylabel(r'$\sigma_{xy}$ $ x 10^{8}$ $[N/m^{2}]$')
plt.xscale('log')
plt.legend()
plt.show()

#Graph Closed Model Polyimide-Substrate Interface Mesh Size vs Sig_xx, Sig_yy and Sig_xy Max_Graph
plt.figure(figsize = (10,10))
plt.scatter(Max_Mesh_size, Closed_Substrate_Interface_Max_Graph_Sig_xx, label = r'Max Graphical $\sigma_{xx}$')
plt.scatter(Max_Mesh_size, Closed_Substrate_Interface_Max_Graph_Sig_yy, label = r'Max Graphical $\sigma_{yy}$')
plt.scatter(Max_Mesh_size, Closed_Substrate_Interface_Max_Graph_Sig_xy, label = r'Max Graphical $\sigma_{xy}$')
plt.title(r'Maximum Stress along Polyimide-Substrate Interface vs Mesh Size for Closed Model')
plt.xlabel(r'Mesh Size [m]')
plt.ylabel(r'$\sigma$ $ x 10^{8}$ $[N/m^{2}]$')
plt.xscale('log')
plt.legend()
plt.show()

#Graph Closed Model Polyimide-Substrate Interface Mesh Size vs Sig_xx comparing Max vs Max_Graph
plt.figure(figsize = (10,10))
plt.scatter(Max_Mesh_size, Closed_Substrate_Interface_Max_Sig_xx, label = r'Max $\sigma_{xx}$')
plt.scatter(Max_Mesh_size, Closed_Substrate_Interface_Max_Graph_Sig_xx, label = r'Max Graphical $\sigma_{xx}$')
plt.title(r'Maximum $Stress_{xx}$ along Polyimide-Substrate Interface vs Mesh Size for Closed Model')
plt.xlabel(r'Mesh Size [m]')
plt.ylabel(r'$\sigma_{xx}$ $ x 10^{8}$ $[N/m^{2}]$')
plt.xscale('log')
plt.legend()
plt.show()

#Graph Closed Model Polyimide-Substrate Interface Mesh Size vs Sig_yy comparing Max vs Max_Graph
plt.figure(figsize = (10,10))
plt.scatter(Max_Mesh_size, Closed_Substrate_Interface_Max_Sig_yy, label = r'Max $\sigma_{yy}$')
plt.scatter(Max_Mesh_size, Closed_Substrate_Interface_Max_Graph_Sig_yy, label = r'Max Graphical $\sigma_{yy}$')
plt.title(r'Maximum $Stress_{yy}$ along Polyimide-Substrate Interface vs Mesh Size for Closed Model')
plt.xlabel(r'Mesh Size [m]')
plt.ylabel(r'$\sigma_{yy}$ $ x 10^{8}$ $[N/m^{2}]$')
plt.xscale('log')
plt.legend()
plt.show()

#Graph Closed Model Polyimide-Substrate Interface Mesh Size vs Sig_xy comparing Max vs Max_Graph
plt.figure(figsize = (10,10))
plt.scatter(Max_Mesh_size, Closed_Substrate_Interface_Max_Sig_xy, label = r'Max $\sigma_{xy}$')
plt.scatter(Max_Mesh_size, Closed_Substrate_Interface_Max_Graph_Sig_xy, label = r'Max Graphical $\sigma_{xy}$')
plt.title(r'Maximum $Stress_{xy}$ along Polyimide-Substrate Interface vs Mesh Size for Closed Model')
plt.xlabel(r'Mesh Size [m]')
plt.ylabel(r'$\sigma$ $ x 10^{8}$ $[N/m^{2}]$')
plt.xscale('log')
plt.legend()
plt.show()

#Graph Open Model Metal-Polyimide Interface Mesh Size vs Sig_xx, Sig_yy and Sig_xy 
plt.figure(figsize = (10,10))
plt.scatter(Max_Mesh_size, Open_Metal_Interface_Max_Graph_Sig_xx, label = r'Max $\sigma_{xx}$')
plt.scatter(Max_Mesh_size, Open_Metal_Interface_Max_Graph_Sig_yy, label = r'Max $\sigma_{yy}$')
plt.scatter(Max_Mesh_size, Open_Metal_Interface_Max_Graph_Sig_xy, label = r'Max $\sigma_{xy}$')
plt.title(r'Maximum Stress along Metal Lead-Polyimide Interface vs Mesh Size for Open Model')
plt.xlabel(r'Mesh Size [m]')
plt.ylabel(r'$\sigma$ $ x 10^{7}$ $[N/m^{2}]$')
plt.xscale('log')
plt.legend()
plt.show()


#Graph Open Model Metal-Polyimide Interface Mesh Size vs Sig_xx 
plt.figure(figsize = (10,10))
plt.scatter(Max_Mesh_size, Open_Metal_Interface_Max_Graph_Sig_xx, label = r'Max $\sigma_{xx}$')
plt.title(r'Maximum $Stress_{xx}$ along Metal Lead-Polyimide Interface vs Mesh Size for Open Model')
plt.xlabel(r'Mesh Size [m]')
plt.ylabel(r'$\sigma_{xx}$ $ x 10^{7}$ $[N/m^{2}]$')
plt.xscale('log')
plt.legend()
plt.show()


#Graph Open Model Metal-Polyimide Interface Mesh Size vs Sig_yy 
plt.figure(figsize = (10,10))
plt.scatter(Max_Mesh_size, Open_Metal_Interface_Max_Graph_Sig_yy, label = r'Max $\sigma_{yy}$')
plt.title(r'Maximum $Stress_{yy}$ along Metal Lead-Polyimide Interface vs Mesh Size for Open Model')
plt.xlabel(r'Mesh Size [m]')
plt.ylabel(r'$\sigma_{yy}$ $ x 10^{7}$ $[N/m^{2}]$')
plt.xscale('log')
plt.legend()
plt.show()


#Graph Open Model Metal-Polyimide Interface Mesh Size vs Sig_xy 
plt.figure(figsize = (10,10))
plt.scatter(Max_Mesh_size, Open_Metal_Interface_Max_Graph_Sig_xy, label = r'Max $\sigma_{xy}$')
plt.title(r'Maximum $Stress_{xy}$ along Metal Lead-Polyimide Interface vs Mesh Size for Open Model')
plt.xlabel(r'Mesh Size [m]')
plt.ylabel(r'$\sigma_{xy}$ $ x 10^{7}$ $[N/m^{2}]$')
plt.xscale('log')
plt.legend()
plt.show()

#Graph Open Model Polyimide-Substrate Interface Mesh Size vs Sig_xx, Sig_yy and Sig_xy 
plt.figure(figsize = (10,10))
plt.scatter(Max_Mesh_size, Open_Substrate_Interface_Max_Graph_Sig_xx, label = r'Max $\sigma_{xx}$')
plt.scatter(Max_Mesh_size, Open_Substrate_Interface_Max_Graph_Sig_yy, label = r'Max $\sigma_{yy}$')
plt.scatter(Max_Mesh_size, Open_Substrate_Interface_Max_Graph_Sig_xy, label = r'Max $\sigma_{xy}$')
plt.title(r'Maximum Stress along Polyimide-Substrate In terface vs Mesh Size for Open Model')
plt.xlabel(r'Mesh Size [m]')
plt.ylabel(r'$\sigma$ $ x 10^{7}$ $[N/m^{2}]$')
plt.xscale('log')
plt.legend()
plt.show()

#Graph Open Model Polyimide-Substrate Interface Mesh Size vs Sig_xx 
plt.figure(figsize = (10,10))
plt.scatter(Max_Mesh_size, Open_Substrate_Interface_Max_Graph_Sig_xx, label = r'Max $\sigma_{xx}$')
plt.title(r'Maximum $Stress_{xx}$ along Polyimide-Substrate In terface vs Mesh Size for Open Model')
plt.xlabel(r'Mesh Size [m]')
plt.ylabel(r'$\sigma_{xx}$ $ x 10^{7}$ $[N/m^{2}]$')
plt.xscale('log')
plt.legend()
plt.show()

#Graph Open Model Polyimide-Substrate Interface Mesh Size vs Sig_yy  
plt.figure(figsize = (10,10))
plt.scatter(Max_Mesh_size, Open_Substrate_Interface_Max_Graph_Sig_yy, label = r'Max $\sigma_{yy}$')
plt.title(r'Maximum $Stress_{yy}$ along Polyimide-Substrate In terface vs Mesh Size for Open Model')
plt.xlabel(r'Mesh Size [m]')
plt.ylabel(r'$\sigma_{yy}$ $ x 10^{7}$ $[N/m^{2}]$')
plt.xscale('log')
plt.legend()
plt.show()

#Graph Open Model Polyimide-Substrate Interface Mesh Size vs Sig_xy 
plt.figure(figsize = (10,10))
plt.scatter(Max_Mesh_size, Open_Substrate_Interface_Max_Graph_Sig_xy, label = r'Max $\sigma_{xy}$')
plt.title(r'Maximum $Stress_{xy}$ along Polyimide-Substrate In terface vs Mesh Size for Open Model')
plt.xlabel(r'Mesh Size [m]')
plt.ylabel(r'$\sigma_{xy}$ $ x 10^{7}$ $[N/m^{2}]$')
plt.xscale('log')
plt.legend()
plt.show()

# %%
import numpy as np
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from oauth2client.client import GoogleCredentials
from google.colab import auth
from scipy.signal import argrelextrema
#first need to import the files from Google drive
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

Mesh_Analysis = drive.CreateFile({'id':'1hyHfl_iAur93-LooG49qCfXhWC7lSOC16dM-STjE4rI'}) 
Mesh_Analysis.GetContentFile('Solid Mechanics Mesh Size vs Stresses.xlsx', mimetype= 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet')

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

Mesh_Analysis = pd.read_excel('Solid Mechanics Mesh Size vs Stresses.xlsx')
print(Mesh_Analysis)

#Closed Model Metal Overhang Sig_xx vs Max Mesh Size
plt.figure(figsize = (10,10))
plt.scatter(Mesh_Analysis['Max_Mesh/m'], Mesh_Analysis['Ave_Sig_xx'], c = 'r', marker = 'x', label = r'$\frac{\int T_{i} dh}{H_{metal}}$')
plt.title('Response of Average Stress in Closed Models Overhang w.r.t Maximum Mesh Size', pad= 20, fontsize = 20)
plt.xlabel(r'Maximum Mesh Size [m]', fontsize = 15)
plt.ylabel(r'$\sigma_{xx}$ $\times 10^8$ in the Overhang $[\frac{N}{m^{2}}]$', fontsize = 15)
plt.xscale('log')
plt.legend(fontsize = 20)
plt.show()

#Closed Model Metal Overhang Sig_xx vs Min Mesh Size
plt.figure(figsize = (10,10))
plt.scatter(Mesh_Analysis['Min_Mesh/m'], Mesh_Analysis['Ave_Sig_xx'], c = 'r', marker = 'x', label = r'$\frac{\int T_{i} dh}{H_{metal lead}}$')
plt.title('Response of Average Stress in Closed Models Overhang w.r.t Minimum Mesh Size', pad= 20, fontsize = 20)
plt.xlabel(r'Minimum Mesh Size [m]', fontsize = 15)
plt.ylabel(r'$\sigma_{xx}$ $\times 10^8$ in the Overhang $[\frac{N}{m^{2}}]$', fontsize = 15)#increase font size of labels + title + legend
plt.xscale('log')
plt.legend( fontsize = 20 )
plt.show()
# Out:
#     Max_Mesh/m  Min_Mesh/m   Ave_Sig_xx  Max_CPM_Sig_xx  \
# 0        0.010    0.000020  228280000.0     164780000.0
# 1        0.020    0.000075  228296000.0     151400000.0
# 2        0.037    0.000125  228316000.0     143680000.0
# 3        0.053    0.000300  283480000.0     136057000.0
# 4        0.067    0.000300  283840000.0     132772000.0
# 5        0.100    0.002000  284200000.0     135130000.0
# 6        0.130    0.006000  284400000.0     134560000.0
# 7        0.200    0.016000  285260000.0     137491000.0
# 8        0.330    0.050000  284960000.0     128120000.0
# 9        0.001    0.000001  282749640.0     239690000.0
# 10       0.002    0.000002  282755940.0     210400000.0
# 11       0.004    0.000004  282770820.0     187650000.0
# 12       0.006    0.000006  282787940.0     176560000.0
# 13       0.008    0.000008  282828740.0     169770000.0
# 14       0.010    0.000010  282807480.0     164770000.0
# 15       0.020    0.000020  282952480.0     151400000.0
# ...

# %%
#Closed Model Metal Interface Sig_xx vs Max Mesh Size
plt.figure(figsize = (10,10))
plt.scatter(Mesh_Analysis['Max_Mesh/m'], Mesh_Analysis['Max_CPM_Sig_xx'], c = 'r', marker = 'x', label = r'$\sigma_{xx}$')
plt.title(r'Response of $\sigma_{xx}$ in Closed Models Metal-Polyimide Interface w.r.t Maximum Mesh Size', pad= 20, fontsize = 20)
plt.xlabel(r'Maximum Mesh Size [m]', fontsize = 15)
plt.ylabel(r'$\sigma_{xx}$ $\times 10^8$ $[\frac{N}{m^{2}}]$', fontsize = 15)
plt.xscale('log')
plt.legend( fontsize = 20)
plt.show()

#Closed Model Metal Interface Sig_xx vs Min Mesh Size
plt.figure(figsize = (10,10))
plt.scatter(Mesh_Analysis['Min_Mesh/m'], Mesh_Analysis['Max_CPM_Sig_xx'], c = 'r', marker = 'x', label = r'$\sigma_{xx}$')
plt.title(r'Response of $\sigma_{xx}$ in Closed Models Metal-Polyimide Interface w.r.t Minimum Mesh Size', pad= 20, fontsize = 20)
plt.xlabel(r'Minimum Mesh Size [m]', fontsize = 15)
plt.ylabel(r'$\sigma_{xx}$ $\times 10^8$ $[\frac{N}{m^{2}}]$', fontsize = 15)
plt.xscale('log')
plt.legend( fontsize = 20)
plt.show()
#Closed Model Metal Interface Sig_yy vs Max Mesh Size
plt.figure(figsize = (10,10))
plt.scatter(Mesh_Analysis['Max_Mesh/m'], Mesh_Analysis['Max_CPM_Sig_yy e [0.55, 0.6]'], c = 'b', marker = 'x', label = r'$\sigma_{yy}$')
plt.title(r'Response of $\sigma_{yy}$ in Closed Models Metal-Polyimide Interface w.r.t Maximum Mesh Size', pad= 20, fontsize = 20)
plt.xlabel(r'Maximum Mesh Size [m]', fontsize = 15)
plt.ylabel(r'$\sigma_{yy}$ $\times 10^7$ $[\frac{N}{m^{2}}]$', fontsize = 15)
plt.xscale('log')
plt.legend(fontsize = 20)
plt.show()
#Closed Model Metal Interface Sig_yy vs Min Mesh Size
plt.figure(figsize = (10,10))
plt.scatter(Mesh_Analysis['Min_Mesh/m'], Mesh_Analysis['Max_CPM_Sig_yy e [0.55, 0.6]'], c = 'b', marker = 'x', label = r'$\sigma_{yy}$')
plt.title(r'Response of $\sigma_{yy}$ in Closed Models Metal-Polyimide Interface w.r.t Minimum Mesh Size', pad= 20, fontsize = 20)
plt.xlabel(r'Minimum Mesh Size [m]', fontsize = 15)
plt.ylabel(r'$\sigma_{yy}$ $\times 10^7$ $[\frac{N}{m^{2}}]$', fontsize = 15)
plt.xscale('log')
plt.legend(fontsize = 20)
plt.show()
#Closed Model Metal Interface Sig_xy vs Max Mesh Size
plt.figure(figsize = (10,10))
plt.scatter(Mesh_Analysis['Max_Mesh/m'], Mesh_Analysis['Max_CPM_Sig_xy e [0.3, 0.4]'], c = 'g', marker = 'x', label = r'$\sigma_{xy}$')
plt.scatter(Mesh_Analysis['Max_Mesh/m'], Mesh_Analysis['Irregularrities_Max_CPM_Sig_xy e [0, 0.05]'], c = 'purple', marker = 'x', label = r'Irregularity $\sigma_{xy}$')
plt.title(r'Response of $\sigma_{xy}$ in Closed Models Metal-Polyimide Interface w.r.t Maximum Mesh Size', pad= 20, fontsize = 20)
plt.xlabel(r'Maximum Mesh Size [m]', fontsize = 15)
plt.ylabel(r'$\sigma_{xy}$ $\times 10^7$ $[\frac{N}{m^{2}}]$', fontsize = 15)
plt.xscale('log')
plt.legend(fontsize = 20)
plt.show()
#Closed Model Metal Interface Sig_xy vs Min Mesh Size
plt.figure(figsize = (10,10))
plt.scatter(Mesh_Analysis['Min_Mesh/m'], Mesh_Analysis['Max_CPM_Sig_xy e [0.3, 0.4]'], c = 'g', marker = 'x', label = r'$\sigma_{xy}$')
plt.scatter(Mesh_Analysis['Min_Mesh/m'], Mesh_Analysis['Irregularrities_Max_CPM_Sig_xy e [0, 0.05]'], c = 'purple', marker = 'x', label = r'Irregularity $\sigma_{xy}$')
plt.title(r'Response of $\sigma_{xy}$ in Closed Models Metal-Polyimide Interface w.r.t Minimum Mesh Size', pad= 20, fontsize = 20)
plt.xlabel(r'Minimum Mesh Size [m]',fontsize = 15)
plt.ylabel(r'$\sigma_{xy}$ $\times 10^7$ $[\frac{N}{m^{2}}]$',fontsize = 15)
plt.xscale('log')
plt.legend(fontsize = 20)
plt.show()
#Closed Model Metal Interface all Stresses vs Max Mesh Size
plt.figure(figsize = (10,10))
plt.scatter(Mesh_Analysis['Max_Mesh/m'], Mesh_Analysis['Max_CPM_Sig_xx'], c = 'r', marker = 'x', label = r'$\sigma_{xx}$')
plt.scatter(Mesh_Analysis['Max_Mesh/m'], Mesh_Analysis['Max_CPM_Sig_yy e [0.55, 0.6]'], c = 'b', marker = '*', label = r'$\sigma_{yy}$')
plt.scatter(Mesh_Analysis['Max_Mesh/m'], Mesh_Analysis['Max_CPM_Sig_xy e [0.3, 0.4]'], c = 'g', marker = 'o', label = r'$\sigma_{xy}$')
plt.title(r'Response of All the Stresses in Closed Models Metal-Polyimide Interface w.r.t Maximum Mesh Size', pad= 20, fontsize = 20)
plt.xlabel(r'Maximum Mesh Size [m]',fontsize = 15)
plt.ylabel(r'$\sigma$ $\times 10^8$ $[\frac{N}{m^{2}}]$',fontsize = 15)
plt.xscale('log')
plt.legend(fontsize = 20)
plt.show()
#Closed Model Metal Interface all Stresses vs Min Mesh Size
plt.figure(figsize = (10,10))
plt.scatter(Mesh_Analysis['Min_Mesh/m'], Mesh_Analysis['Max_CPM_Sig_xx'], c = 'r', marker = 'x', label = r'$\sigma_{xx}$')
plt.scatter(Mesh_Analysis['Min_Mesh/m'], Mesh_Analysis['Max_CPM_Sig_yy e [0.55, 0.6]'], c = 'b', marker = '*', label = r'$\sigma_{yy}$')
plt.scatter(Mesh_Analysis['Min_Mesh/m'], Mesh_Analysis['Max_CPM_Sig_xy e [0.3, 0.4]'], c = 'g', marker = 'o', label = r'$\sigma_{xy}$')
plt.title(r'Response of All the Stresses in Closed Models Metal-Polyimide Interface w.r.t Minimum Mesh Size', pad= 20, fontsize = 20)
plt.xlabel(r'Minimum Mesh Size [m]',fontsize = 15)
plt.ylabel(r'$\sigma$ $\times 10^8$ $[\frac{N}{m^{2}}]$',fontsize = 15)
plt.xscale('log')
plt.legend(fontsize = 20)
plt.show()

# %%
#Closed Model Substrate Interface Sig_xx vs Max Mesh Size
plt.figure(figsize = (10,10))
plt.scatter(Mesh_Analysis['Max_Mesh/m'], Mesh_Analysis['Max_CSP_Sig_xx'], c = 'r', marker = 'x', label = r'$\sigma_{xx}$')
plt.title(r'Response of $\sigma_{xx}$ in Closed Models Polyimide-Substrate Interface w.r.t Maximum Mesh Size', pad= 20, fontsize = 20)
plt.xlabel(r'Maximum Mesh Size [m]',fontsize = 15)
plt.ylabel(r'$\sigma_{xx}$ $\times 10^8$ $[\frac{N}{m^{2}}]$',fontsize = 15)
plt.xscale('log')
plt.legend(fontsize = 20)
plt.show()
#Closed Model Substrate Interface Sig_xx vs Min Mesh Size
plt.figure(figsize = (10,10))
plt.scatter(Mesh_Analysis['Min_Mesh/m'], Mesh_Analysis['Max_CSP_Sig_xx'], c = 'r', marker = 'x', label = r'$\sigma_{xx}$')
plt.title(r'Response of $\sigma_{xx}$ in Closed Models Polyimide-Substrate Interface w.r.t Minimum Mesh Size', pad= 20, fontsize = 20)
plt.xlabel(r'Minimum Mesh Size [m]',fontsize = 15)
plt.ylabel(r'$\sigma_{xx}$ $\times 10^8$ $[\frac{N}{m^{2}}]$',fontsize = 15)
plt.xscale('log')
plt.legend(fontsize = 20)
plt.show()
#Closed Model Substrate Interface Sig_yy vs Max Mesh Size
plt.figure(figsize = (10,10))
plt.scatter(Mesh_Analysis['Max_Mesh/m'], Mesh_Analysis['Max_CSP_Sig_yy'], c = 'b', marker = 'x', label = r'$\sigma_{yy}$')
plt.title(r'Response of $\sigma_{yy}$ in Closed Models Polyimide-Substrate Interface w.r.t Maximum Mesh Size', pad= 20, fontsize = 20)
plt.xlabel(r'Maximum Mesh Size [m]',fontsize = 15)
plt.ylabel(r'$\sigma_{yy}$ $\times 10^8$ $[\frac{N}{m^{2}}]$',fontsize = 15)
plt.xscale('log')
plt.legend(fontsize = 20)
plt.show()
#Closed Model Substrate Interface Sig_yy vs Min Mesh Size
plt.figure(figsize = (10,10))
plt.scatter(Mesh_Analysis['Min_Mesh/m'], Mesh_Analysis['Max_CSP_Sig_yy'], c = 'b', marker = 'x', label = r'$\sigma_{yy}$')
plt.title(r'Response of $\sigma_{yy}$ in Closed Models Polyimide-Substrate Interface w.r.t Minimum Mesh Size', pad= 20, fontsize = 20)
plt.xlabel(r'Minimum Mesh Size [m]',fontsize = 15)
plt.ylabel(r'$\sigma_{yy}$ $\times 10^8$ $[\frac{N}{m^{2}}]$',fontsize = 15)
plt.xscale('log')
plt.legend(fontsize = 20)
plt.show()
#Closed Model Substrate Interface Sig_xy vs Max Mesh Size
plt.figure(figsize = (10,10))
plt.scatter(Mesh_Analysis['Max_Mesh/m'], Mesh_Analysis['Max_CSP_Sig_xy e [0.95, 1]'], c = 'g', marker = 'x', label = r'$\sigma_{xy}$')
plt.title(r'Response of $\sigma_{xy}$ in Closed Models Polyimide-Substrate Interface w.r.t Maximum Mesh Size', pad= 20, fontsize = 20)
plt.xlabel(r'Maximum Mesh Size [m]',fontsize = 15)
plt.ylabel(r'$\sigma_{xy}$ $\times 10^8$ $[\frac{N}{m^{2}}]$',fontsize = 15)
plt.xscale('log')
plt.legend(fontsize = 20)
plt.show()
#Closed Model Substrate Interface Sig_xy vs Min Mesh Size
plt.figure(figsize = (10,10))
plt.scatter(Mesh_Analysis['Min_Mesh/m'], Mesh_Analysis['Max_CSP_Sig_xy e [0.95, 1]'], c = 'g', marker = 'x', label = r'$\sigma_{xy}$')
plt.title(r'Response of $\sigma_{xy}$ in Closed Models Polyimide-Substrate Interface w.r.t Minimum Mesh Size', pad= 20, fontsize = 20)
plt.xlabel(r'Minimum Mesh Size [m]',fontsize = 15)
plt.ylabel(r'$\sigma_{xy}$ $\times 10^8$ $[\frac{N}{m^{2}}]$',fontsize = 15)
plt.xscale('log')
plt.legend(fontsize = 20)
plt.show()
#Closed Model Substrate Interface all Stresses vs Max Mesh Size
plt.figure(figsize = (10,10))
plt.scatter(Mesh_Analysis['Max_Mesh/m'], Mesh_Analysis['Max_CSP_Sig_xx'], c = 'r', marker = 'x', label = r'$\sigma_{xx}$')
plt.scatter(Mesh_Analysis['Max_Mesh/m'], Mesh_Analysis['Max_CSP_Sig_yy'], c = 'b', marker = '*', label = r'$\sigma_{yy}$')
plt.scatter(Mesh_Analysis['Max_Mesh/m'], Mesh_Analysis['Max_CSP_Sig_xy e [0.95, 1]'], c = 'g', marker = 'o', label = r'$\sigma_{xy}$')
plt.title(r'Response of All the Stresses in Closed Models Metal-Polyimide Interface w.r.t Maximum Mesh Size', pad= 20, fontsize = 20)
plt.xlabel(r'Maximum Mesh Size [m]',fontsize = 15)
plt.ylabel(r'$\sigma$ $\times 10^8$ $[\frac{N}{m^{2}}]$',fontsize = 15)
plt.xscale('log')
plt.legend(fontsize = 20)
plt.show()
#Closed Model Substrate Interface all Stresses vs Min Mesh Size
plt.figure(figsize = (10,10))
plt.scatter(Mesh_Analysis['Min_Mesh/m'], Mesh_Analysis['Max_CSP_Sig_xx'], c = 'r', marker = 'x', label = r'$\sigma_{xx}$')
plt.scatter(Mesh_Analysis['Min_Mesh/m'], Mesh_Analysis['Max_CSP_Sig_yy'], c = 'b', marker = '*', label = r'$\sigma_{yy}$')
plt.scatter(Mesh_Analysis['Min_Mesh/m'], Mesh_Analysis['Max_CSP_Sig_xy e [0.95, 1]'], c = 'g', marker = 'o', label = r'$\sigma_{xy}$')
plt.title(r'Response of All the Stresses in Closed Models Metal-Polyimide Interface w.r.t Minimum Mesh Size', pad= 20, fontsize = 20)
plt.xlabel(r'Minimum Mesh Size [m]',fontsize = 15)
plt.ylabel(r'$\sigma$ $\times 10^8$ $[\frac{N}{m^{2}}]$',fontsize = 15)
plt.xscale('log')
plt.legend(fontsize = 20)
plt.show()

# %%
#Open Model Metal Interface Sig_xx vs Max Mesh Size
plt.figure(figsize = (10,10))
plt.scatter(Mesh_Analysis['Max_Mesh/m'], Mesh_Analysis['Max_OPM_Sig_xx'], c = 'r', marker = 'x', label = r'$\sigma_{xx}$')
plt.title(r'Response of $\sigma_{xx}$ in Open Models Metal-Polyimide Interface w.r.t Maximum Mesh Size', pad= 20, fontsize = 20)
plt.xlabel(r'Maximum Mesh Size [m]',fontsize = 15)
plt.ylabel(r'$\sigma_{xx}$ $\times 10^7$ $[\frac{N}{m^{2}}]$',fontsize = 15)
plt.xscale('log')
plt.legend(fontsize = 20)
plt.show()
#Open Model Metal Interface Sig_xx vs Min Mesh Size
plt.figure(figsize = (10,10))
plt.scatter(Mesh_Analysis['Min_Mesh/m'], Mesh_Analysis['Max_OPM_Sig_xx'], c = 'r', marker = 'x', label = r'$\sigma_{xx}$')
plt.title(r'Response of $\sigma_{xx}$ in Open Models Metal-Polyimide Interface w.r.t Minimum Mesh Size', pad= 20, fontsize = 20)
plt.xlabel(r'Minimum Mesh Size [m]',fontsize = 15)
plt.ylabel(r'$\sigma_{xx}$ $\times 10^7$ $[\frac{N}{m^{2}}]$',fontsize = 15)
plt.xscale('log')
plt.legend(fontsize = 20)
plt.show()
#Open Model Metal Interface Sig_yy vs Max Mesh Size
plt.figure(figsize = (10,10))
plt.scatter(Mesh_Analysis['Max_Mesh/m'], Mesh_Analysis['Max_OPM_Sig_yy'], c = 'r', marker = 'x', label = r'$\sigma_{yy}$')
plt.title(r'Response of $\sigma_{yy}$ in Open Models Metal-Polyimide Interface w.r.t Maximum Mesh Size', pad= 20, fontsize = 20)
plt.xlabel(r'Maximum Mesh Size [m]',fontsize = 15)
plt.ylabel(r'$\sigma_{yy}$ $\times 10^7$ $[\frac{N}{m^{2}}]$',fontsize = 15)
plt.xscale('log')
plt.legend(fontsize = 20)
plt.show()
#Open Model Metal Interface Sig_yy vs Min Mesh Size
plt.figure(figsize = (10,10))
plt.scatter(Mesh_Analysis['Min_Mesh/m'], Mesh_Analysis['Max_OPM_Sig_yy'], c = 'r', marker = 'x', label = r'$\sigma_{yy}$')
plt.title(r'Response of $\sigma_{yy}$ in Open Models Metal-Polyimide Interface w.r.t Minimum Mesh Size', pad= 20, fontsize = 20)
plt.xlabel(r'Maximum Mesh Size [m]',fontsize = 15)
plt.ylabel(r'$\sigma_{yy}$ $\times 10^7$ $[\frac{N}{m^{2}}]$',fontsize = 15)
plt.xscale('log')
plt.legend(fontsize = 20)
plt.show()
#Open Model Metal Interface Sig_xy vs Max Mesh Size
plt.figure(figsize = (10,10))
plt.scatter(Mesh_Analysis['Max_Mesh/m'], Mesh_Analysis['Max_OPM_Sig_xy'], c = 'r', marker = 'x', label = r'$\sigma_{xy}$')
plt.title(r'Response of $\sigma_{xy}$ in Open Models Metal-Polyimide Interface w.r.t Maximum Mesh Size', pad= 20, fontsize = 20)
plt.xlabel(r'Maximum Mesh Size [m]',fontsize = 15)
plt.ylabel(r'$\sigma_{xy}$ $\times 10^7$ $[\frac{N}{m^{2}}]$',fontsize = 15)
plt.xscale('log')
plt.legend(fontsize = 20)
plt.show()
#Open Model Metal Interface Sig_xy vs Min Mesh Size
plt.figure(figsize = (10,10))
plt.scatter(Mesh_Analysis['Min_Mesh/m'], Mesh_Analysis['Max_OPM_Sig_xy'], c = 'r', marker = 'x', label = r'$\sigma_{xy}$')
plt.title(r'Response of $\sigma_{xy}$ in Open Models Metal-Polyimide Interface w.r.t Minimum Mesh Size', pad= 20, fontsize = 20)
plt.xlabel(r'Maximum Mesh Size [m]',fontsize = 15)
plt.ylabel(r'$\sigma_{xy}$ $\times 10^7$ $[\frac{N}{m^{2}}]$',fontsize = 15)
plt.xscale('log')
plt.legend(fontsize = 20)
plt.show()
#Open Model Metal Interface all Stresses vs Max Mesh Size
plt.figure(figsize = (10,10))
plt.scatter(Mesh_Analysis['Max_Mesh/m'], Mesh_Analysis['Max_OPM_Sig_xx'], c = 'r', marker = 'x', label = r'$\sigma_{xx}$')
plt.scatter(Mesh_Analysis['Max_Mesh/m'], Mesh_Analysis['Max_OPM_Sig_yy'], c = 'b', marker = '*', label = r'$\sigma_{yy}$')
plt.scatter(Mesh_Analysis['Max_Mesh/m'], Mesh_Analysis['Max_OPM_Sig_xy'], c = 'g', marker = 'o', label = r'$\sigma_{xy}$')
plt.title(r'Response of All the Stresses in Closed Models Metal-Polyimide Interface w.r.t Maximum Mesh Size', pad= 20, fontsize = 20)
plt.xlabel(r'Maximum Mesh Size [m]',fontsize = 15)
plt.ylabel(r'$\sigma$ $\times 10^7$ $[\frac{N}{m^{2}}]$',fontsize = 15)
plt.xscale('log')
plt.legend(fontsize = 20)
plt.show()
#Open Model Metal Interface all Stresses vs Min Mesh Size
plt.figure(figsize = (10,10))
plt.scatter(Mesh_Analysis['Min_Mesh/m'], Mesh_Analysis['Max_OPM_Sig_xx'], c = 'r', marker = 'x', label = r'$\sigma_{xx}$')
plt.scatter(Mesh_Analysis['Min_Mesh/m'], Mesh_Analysis['Max_OPM_Sig_yy'], c = 'b', marker = '*', label = r'$\sigma_{yy}$')
plt.scatter(Mesh_Analysis['Min_Mesh/m'], Mesh_Analysis['Max_OPM_Sig_xy'], c = 'g', marker = 'o', label = r'$\sigma_{xy}$')
plt.title(r'Response of All the Stresses in Closed Models Metal-Polyimide Interface w.r.t Minimum Mesh Size', pad= 20, fontsize = 20)
plt.xlabel(r'Minimum Mesh Size [m]',fontsize = 15)
plt.ylabel(r'$\sigma$ $\times 10^7$ $[\frac{N}{m^{2}}]$',fontsize = 15)
plt.xscale('log')
plt.legend(fontsize = 20)
plt.show()

# %%
#Open Model Substrate Interface Sig_xx vs Max Mesh Size
plt.figure(figsize = (10,10))
plt.scatter(Mesh_Analysis['Max_Mesh/m'], Mesh_Analysis['Max_OSP_Sig_xx'], c = 'r', marker = 'x', label = r'$\sigma_{xx}$')
plt.title(r'Response of $\sigma_{xx}$ in Open Models Polyimide-Substrate Interface w.r.t Maximum Mesh Size', pad= 20, fontsize = 20)
plt.xlabel(r'Maximum Mesh Size [m]',fontsize = 15)
plt.ylabel(r'$\sigma_{xx}$ $\times 10^8$ $[\frac{N}{m^{2}}]$',fontsize = 15)
plt.xscale('log')
plt.legend(fontsize = 20)
plt.show()
#Open Model Substrate Interface Sig_xx vs Min Mesh Size
plt.figure(figsize = (10,10))
plt.scatter(Mesh_Analysis['Min_Mesh/m'], Mesh_Analysis['Max_OSP_Sig_xx'], c = 'r', marker = 'x', label = r'$\sigma_{xx}$')
plt.title(r'Response of $\sigma_{xx}$ in Open Models Polyimide-Substrate Interface w.r.t Minimum Mesh Size', pad= 20, fontsize = 20)
plt.xlabel(r'Minimum Mesh Size [m]',fontsize = 15)
plt.ylabel(r'$\sigma_{xx}$ $\times 10^8$ $[\frac{N}{m^{2}}]$',fontsize = 15)
plt.xscale('log')
plt.legend(fontsize = 20)
plt.show()
#Open Model Substrate Interface Sig_yy vs Max Mesh Size
plt.figure(figsize = (10,10))
plt.scatter(Mesh_Analysis['Max_Mesh/m'], Mesh_Analysis['Max_OSP_Sig_yy'], c = 'r', marker = 'x', label = r'$\sigma_{yy}$')
plt.title(r'Response of $\sigma_{yy}$ in Open Models Polyimide-Substrate Interface w.r.t Maximum Mesh Size', pad= 20, fontsize = 20)
plt.xlabel(r'Maximum Mesh Size [m]',fontsize = 15)
plt.ylabel(r'$\sigma_{yy}$ $\times 10^8$ $[\frac{N}{m^{2}}]$',fontsize = 15)
plt.xscale('log')
plt.legend(fontsize = 20)
plt.show()
#Open Model Substrate Interface Sig_yy vs Min Mesh Size
plt.figure(figsize = (10,10))
plt.scatter(Mesh_Analysis['Min_Mesh/m'], Mesh_Analysis['Max_OSP_Sig_yy'], c = 'r', marker = 'x', label = r'$\sigma_{yy}$')
plt.title(r'Response of $\sigma_{yy}$ in Open Models Polyimide-Substrate Interface w.r.t Minimum Mesh Size', pad= 20, fontsize = 20)
plt.xlabel(r'Maximum Mesh Size [m]',fontsize = 15)
plt.ylabel(r'$\sigma_{yy}$ $\times 10^8$ $[\frac{N}{m^{2}}]$',fontsize = 15)
plt.xscale('log')
plt.legend(fontsize = 20)
plt.show()
#Open Model Substrate Interface Sig_xy vs Max Mesh Size
plt.figure(figsize = (10,10))
plt.scatter(Mesh_Analysis['Max_Mesh/m'], Mesh_Analysis['Max_OSP_Sig_xy'], c = 'r', marker = 'x', label = r'$\sigma_{xy}$')
plt.title(r'Response of $\sigma_{xy}$ in Open Models Polyimide-Substrate Interface w.r.t Maximum Mesh Size', pad= 20,fontsize = 20)
plt.xlabel(r'Maximum Mesh Size [m]',fontsize = 15)
plt.ylabel(r'$\sigma_{xy}$ $\times 10^8$ $[\frac{N}{m^{2}}]$',fontsize = 15)
plt.xscale('log')
plt.legend(fontsize = 20)
plt.show()
#Open Model Substrate Interface Sig_xy vs Min Mesh Size
plt.figure(figsize = (10,10))
plt.scatter(Mesh_Analysis['Min_Mesh/m'], Mesh_Analysis['Max_OSP_Sig_xy'], c = 'r', marker = 'x', label = r'$\sigma_{xy}$')
plt.title(r'Response of $\sigma_{xy}$ in Open Models Polyimide-Substrate Interface w.r.t Minimum Mesh Size', pad= 20,fontsize = 20)
plt.xlabel(r'Maximum Mesh Size [m]',fontsize = 15)
plt.ylabel(r'$\sigma_{xy}$ $\times 10^8$ $[\frac{N}{m^{2}}]$',fontsize = 15)
plt.xscale('log')
plt.legend(fontsize = 20)
plt.show()
#Open Model Substrate Interface all Stresses vs Max Mesh Size
plt.figure(figsize = (10,10))
plt.scatter(Mesh_Analysis['Max_Mesh/m'], Mesh_Analysis['Max_OSP_Sig_xx'], c = 'r', marker = 'x', label = r'$\sigma_{xx}$')
plt.scatter(Mesh_Analysis['Max_Mesh/m'], Mesh_Analysis['Max_OSP_Sig_yy'], c = 'b', marker = '*', label = r'$\sigma_{yy}$')
plt.scatter(Mesh_Analysis['Max_Mesh/m'], Mesh_Analysis['Max_OSP_Sig_xy'], c = 'g', marker = 'o', label = r'$\sigma_{xy}$')
plt.title(r'Response of All the Stresses in Closed Models Polyimide-Substrate Interface w.r.t Maximum Mesh Size', pad= 20,fontsize = 20)
plt.xlabel(r'Maximum Mesh Size [m]',fontsize = 15)
plt.ylabel(r'$\sigma$ $\times 10^8$ $[\frac{N}{m^{2}}]$',fontsize = 15)
plt.xscale('log')
plt.legend(fontsize = 20)
plt.show()
#Open Model Substrate Interface all Stresses vs Min Mesh Size
plt.figure(figsize = (10,10))
plt.scatter(Mesh_Analysis['Min_Mesh/m'], Mesh_Analysis['Max_OSP_Sig_xx'], c = 'r', marker = 'x', label = r'$\sigma_{xx}$')
plt.scatter(Mesh_Analysis['Min_Mesh/m'], Mesh_Analysis['Max_OSP_Sig_yy'], c = 'b', marker = '*', label = r'$\sigma_{yy}$')
plt.scatter(Mesh_Analysis['Min_Mesh/m'], Mesh_Analysis['Max_OSP_Sig_xy'], c = 'g', marker = 'o', label = r'$\sigma_{xy}$')
plt.title(r'Response of All the Stresses in Closed Models Polyimide-Substrate Interface w.r.t Minimum Mesh Size', pad= 20, fontsize = 20)
plt.xlabel(r'Minimum Mesh Size [m]',fontsize = 15)
plt.ylabel(r'$\sigma$  $\times 10^8$ $[\frac{N}{m^{2}}]$',fontsize = 15)
plt.xscale('log')
plt.legend(fontsize = 20)
plt.show()
